# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, roc_curve, balanced_accuracy_score
from data_preparation import *
from data_splitting import *
from cross_validation_DL import *
# Out:
# Total number of instances: 2000
#
#  Fold 1
#
# Epoch 1/45
# 35/35 - 31s - loss: 0.7085 - acc: 0.5348 - val_loss: 0.6947 - val_acc: 0.4464 - 31s/epoch - 899ms/step
# Epoch 2/45
# 35/35 - 23s - loss: 0.6935 - acc: 0.5000 - val_loss: 0.6971 - val_acc: 0.4464 - 23s/epoch - 652ms/step
# Epoch 3/45
# 35/35 - 24s - loss: 0.6934 - acc: 0.5161 - val_loss: 0.6924 - val_acc: 0.5143 - 24s/epoch - 677ms/step
# Epoch 4/45
# 35/35 - 19s - loss: 0.6923 - acc: 0.5196 - val_loss: 0.7019 - val_acc: 0.4464 - 19s/epoch - 550ms/step
# Epoch 5/45
# 35/35 - 25s - loss: 0.6863 - acc: 0.5518 - val_loss: 0.6633 - val_acc: 0.5536 - 25s/epoch - 704ms/step
# Epoch 6/45
# 35/35 - 30s - loss: 0.6860 - acc: 0.5580 - val_loss: 0.6704 - val_acc: 0.5929 - 30s/epoch - 861ms/step
# Epoch 7/45
# 35/35 - 25s - loss: 0.6771 - acc: 0.5964 - val_loss: 0.6726 - val_acc: 0.5607 - 25s/epoch - 711ms/step
# Epoch 8/45
# 35/35 - 24s - loss: 0.6775 - acc: 0.5884 - val_loss: 0.6818 - val_acc: 0.5321 - 24s/epoch - 689ms/step
# Epoch 9/45
# 35/35 - 19s - loss: 0.6762 - acc: 0.5705 - val_loss: 0.6821 - val_acc: 0.5464 - 19s/epoch - 530ms/step
# Epoch 10/45
# 35/35 - 21s - loss: 0.6613 - acc: 0.5982 - val_loss: 0.6521 - val_acc: 0.6000 - 21s/epoch - 612ms/step
# Epoch 11/45
# 35/35 - 20s - loss: 0.6614 - acc: 0.6062 - val_loss: 0.6807 - val_acc: 0.5357 - 20s/epoch - 567ms/step
# Epoch 12/45
# 35/35 - 21s - loss: 0.6478 - acc: 0.6330 - val_loss: 0.6624 - val_acc: 0.5786 - 21s/epoch - 601ms/step
# Epoch 13/45
# 35/35 - 19s - loss: 0.6408 - acc: 0.6348 - val_loss: 0.6452 - val_acc: 0.6250 - 19s/epoch - 537ms/step
# Epoch 14/45
# 35/35 - 20s - loss: 0.6301 - acc: 0.6438 - val_loss: 0.6264 - val_acc: 0.6750 - 20s/epoch - 567ms/step
# Epoch 15/45
# 35/35 - 19s - loss: 0.6192 - acc: 0.6491 - val_loss: 0.6410 - val_acc: 0.6000 - 19s/epoch - 555ms/step
# Epoch 16/45
# 35/35 - 20s - loss: 0.6301 - acc: 0.6384 - val_loss: 0.6476 - val_acc: 0.6036 - 20s/epoch - 571ms/step
# Epoch 17/45
# 35/35 - 21s - loss: 0.6141 - acc: 0.6696 - val_loss: 0.6299 - val_acc: 0.6393 - 21s/epoch - 590ms/step
# Epoch 18/45
# 35/35 - 20s - loss: 0.6117 - acc: 0.6652 - val_loss: 0.6652 - val_acc: 0.5464 - 20s/epoch - 567ms/step
# Epoch 19/45
# Epoch 5/45
# 35/35 - 9s - loss: 0.6739 - accuracy: 0.6009 - val_loss: 0.6622 - val_accuracy: 0.6464 - 9s/epoch - 249ms/step
# Epoch 6/45
# 35/35 - 8s - loss: 0.6726 - accuracy: 0.6009 - val_loss: 0.6638 - val_accuracy: 0.6214 - 8s/epoch - 227ms/step
# Epoch 7/45
# 35/35 - 8s - loss: 0.6720 - accuracy: 0.5955 - val_loss: 0.6525 - val_accuracy: 0.6643 - 8s/epoch - 239ms/step
# Epoch 8/45
# 35/35 - 8s - loss: 0.6676 - accuracy: 0.5955 - val_loss: 0.6781 - val_accuracy: 0.5571 - 8s/epoch - 230ms/step
# Epoch 9/45
# 35/35 - 8s - loss: 0.6647 - accuracy: 0.5982 - val_loss: 0.6478 - val_accuracy: 0.6643 - 8s/epoch - 241ms/step
# Epoch 10/45
# 35/35 - 9s - loss: 0.6627 - accuracy: 0.6036 - val_loss: 0.6599 - val_accuracy: 0.6179 - 9s/epoch - 265ms/step
# Epoch 11/45
# 35/35 - 8s - loss: 0.6643 - accuracy: 0.6080 - val_loss: 0.6424 - val_accuracy: 0.6393 - 8s/epoch - 237ms/step
# Epoch 12/45
# 35/35 - 9s - loss: 0.6616 - accuracy: 0.5964 - val_loss: 0.6452 - val_accuracy: 0.6500 - 9s/epoch - 245ms/step
# Epoch 13/45
# 35/35 - 8s - loss: 0.6564 - accuracy: 0.6286 - val_loss: 0.6534 - val_accuracy: 0.6250 - 8s/epoch - 234ms/step
# Epoch 14/45
# 35/35 - 9s - loss: 0.6539 - accuracy: 0.6054 - val_loss: 0.6481 - val_accuracy: 0.6536 - 9s/epoch - 260ms/step
# Epoch 15/45
# 35/35 - 8s - loss: 0.6530 - accuracy: 0.6223 - val_loss: 0.6602 - val_accuracy: 0.6107 - 8s/epoch - 241ms/step
# Epoch 16/45
# 35/35 - 9s - loss: 0.6499 - accuracy: 0.6277 - val_loss: 0.6366 - val_accuracy: 0.6786 - 9s/epoch - 263ms/step
# Epoch 17/45
# 35/35 - 9s - loss: 0.6485 - accuracy: 0.6295 - val_loss: 0.6412 - val_accuracy: 0.6571 - 9s/epoch - 264ms/step
# Epoch 18/45
# 35/35 - 9s - loss: 0.6490 - accuracy: 0.6205 - val_loss: 0.6480 - val_accuracy: 0.6357 - 9s/epoch - 261ms/step
# Epoch 19/45
# 35/35 - 9s - loss: 0.6483 - accuracy: 0.6304 - val_loss: 0.6685 - val_accuracy: 0.6071 - 9s/epoch - 258ms/step
# Epoch 20/45
# 35/35 - 9s - loss: 0.6467 - accuracy: 0.6259 - val_loss: 0.6465 - val_accuracy: 0.6393 - 9s/epoch - 257ms/step
# Epoch 21/45
# 35/35 - 9s - loss: 0.6435 - accuracy: 0.6375 - val_loss: 0.6344 - val_accuracy: 0.6571 - 9s/epoch - 266ms/step
# Epoch 22/45
# 35/35 - 9s - loss: 0.6445 - accuracy: 0.6241 - val_loss: 0.6568 - val_accuracy: 0.6250 - 9s/epoch - 246ms/step
# Epoch 23/45
# 35/35 - 9s - loss: 0.6399 - accuracy: 0.6313 - val_loss: 0.6735 - val_accuracy: 0.5929 - 9s/epoch - 265ms/step
# Epoch 24/45
# 35/35 - 9s - loss: 0.6441 - accuracy: 0.6205 - val_loss: 0.6465 - val_accuracy: 0.6429 - 9s/epoch - 243ms/step
# Epoch 25/45
# 35/35 - 9s - loss: 0.6449 - accuracy: 0.6330 - val_loss: 0.6335 - val_accuracy: 0.6750 - 9s/epoch - 258ms/step
# Epoch 26/45
# 35/35 - 8s - loss: 0.6433 - accuracy: 0.6313 - val_loss: 0.6333 - val_accuracy: 0.6679 - 8s/epoch - 224ms/step
# Epoch 27/45
# 35/35 - 9s - loss: 0.6389 - accuracy: 0.6357 - val_loss: 0.6332 - val_accuracy: 0.6679 - 9s/epoch - 247ms/step
# Epoch 28/45
# 35/35 - 8s - loss: 0.6371 - accuracy: 0.6429 - val_loss: 0.6467 - val_accuracy: 0.6357 - 8s/epoch - 235ms/step
# Epoch 29/45
# 35/35 - 8s - loss: 0.6363 - accuracy: 0.6509 - val_loss: 0.6339 - val_accuracy: 0.6643 - 8s/epoch - 241ms/step
# Epoch 30/45
# 35/35 - 8s - loss: 0.6386 - accuracy: 0.6509 - val_loss: 0.6262 - val_accuracy: 0.6393 - 8s/epoch - 234ms/step
# Epoch 31/45
# 35/35 - 8s - loss: 0.6380 - accuracy: 0.6339 - val_loss: 0.6312 - val_accuracy: 0.6714 - 8s/epoch - 236ms/step
# Epoch 32/45
# 35/35 - 8s - loss: 0.6403 - accuracy: 0.6321 - val_loss: 0.6264 - val_accuracy: 0.6893 - 8s/epoch - 226ms/step
# Epoch 33/45
# 35/35 - 8s - loss: 0.6323 - accuracy: 0.6464 - val_loss: 0.6304 - val_accuracy: 0.6179 - 8s/epoch - 237ms/step
# Epoch 34/45
# 35/35 - 8s - loss: 0.6386 - accuracy: 0.6429 - val_loss: 0.6550 - val_accuracy: 0.6214 - 8s/epoch - 240ms/step
# Epoch 35/45
# 35/35 - 8s - loss: 0.6367 - accuracy: 0.6482 - val_loss: 0.6402 - val_accuracy: 0.6393 - 8s/epoch - 235ms/step
# Epoch 36/45
# 35/35 - 8s - loss: 0.6318 - accuracy: 0.6536 - val_loss: 0.6420 - val_accuracy: 0.6357 - 8s/epoch - 241ms/step
# Epoch 37/45
# 35/35 - 8s - loss: 0.6321 - accuracy: 0.6554 - val_loss: 0.6276 - val_accuracy: 0.7000 - 8s/epoch - 236ms/step
# Epoch 38/45
# 35/35 - 9s - loss: 0.6295 - accuracy: 0.6580 - val_loss: 0.6374 - val_accuracy: 0.6393 - 9s/epoch - 271ms/step
# Epoch 39/45
# 35/35 - 8s - loss: 0.6366 - accuracy: 0.6420 - val_loss: 0.6237 - val_accuracy: 0.6893 - 8s/epoch - 234ms/step
# Epoch 40/45
# 35/35 - 9s - loss: 0.6359 - accuracy: 0.6491 - val_loss: 0.6243 - val_accuracy: 0.6929 - 9s/epoch - 247ms/step
# Epoch 41/45
# 35/35 - 8s - loss: 0.6286 - accuracy: 0.6625 - val_loss: 0.6270 - val_accuracy: 0.6929 - 8s/epoch - 233ms/step
# Epoch 42/45
# 35/35 - 9s - loss: 0.6330 - accuracy: 0.6366 - val_loss: 0.6287 - val_accuracy: 0.6679 - 9s/epoch - 253ms/step
# Epoch 43/45
# 35/35 - 8s - loss: 0.6293 - accuracy: 0.6518 - val_loss: 0.6280 - val_accuracy: 0.6786 - 8s/epoch - 229ms/step
# Epoch 44/45
# 35/35 - 9s - loss: 0.6271 - accuracy: 0.6580 - val_loss: 0.6269 - val_accuracy: 0.6929 - 9s/epoch - 264ms/step
# Epoch 45/45
# 35/35 - 9s - loss: 0.6305 - accuracy: 0.6518 - val_loss: 0.6454 - val_accuracy: 0.6357 - 9s/epoch - 258ms/step
# 9/9 [==============================] - 2s 223ms/step - loss: 0.6454 - accuracy: 0.6357
#
#  Fold 1 - ResNet Validation Accuracy: 0.6357142925262451
#
# Epoch 1/45
# 35/35 - 22s - loss: 1.2447 - accuracy: 0.6187 - val_loss: 0.5626 - val_accuracy: 0.7250 - 22s/epoch - 627ms/step
# Epoch 2/45
# 35/35 - 9s - loss: 0.5133 - accuracy: 0.7375 - val_loss: 0.5369 - val_accuracy: 0.7357 - 9s/epoch - 260ms/step
# Epoch 3/45
# 35/35 - 11s - loss: 0.4252 - accuracy: 0.8054 - val_loss: 0.5208 - val_accuracy: 0.7679 - 11s/epoch - 312ms/step
# Epoch 4/45
# 35/35 - 11s - loss: 0.3747 - accuracy: 0.8313 - val_loss: 0.4920 - val_accuracy: 0.7750 - 11s/epoch - 318ms/step
# Epoch 5/45
# 35/35 - 11s - loss: 0.3083 - accuracy: 0.8741 - val_loss: 0.4898 - val_accuracy: 0.7893 - 11s/epoch - 315ms/step
# Epoch 6/45
# 35/35 - 11s - loss: 0.2692 - accuracy: 0.8875 - val_loss: 0.5016 - val_accuracy: 0.8000 - 11s/epoch - 310ms/step
# Epoch 7/45
# 35/35 - 10s - loss: 0.2231 - accuracy: 0.9152 - val_loss: 0.4985 - val_accuracy: 0.7929 - 10s/epoch - 295ms/step
# Epoch 8/45
# 35/35 - 11s - loss: 0.1731 - accuracy: 0.9491 - val_loss: 0.6254 - val_accuracy: 0.7357 - 11s/epoch - 312ms/step
# Epoch 9/45
# 35/35 - 11s - loss: 0.1442 - accuracy: 0.9518 - val_loss: 0.5114 - val_accuracy: 0.8107 - 11s/epoch - 309ms/step
# Epoch 10/45
# 35/35 - 10s - loss: 0.1096 - accuracy: 0.9732 - val_loss: 0.5264 - val_accuracy: 0.8000 - 10s/epoch - 281ms/step
# Epoch 11/45
# 35/35 - 10s - loss: 0.0870 - accuracy: 0.9768 - val_loss: 0.5353 - val_accuracy: 0.8357 - 10s/epoch - 296ms/step
# Epoch 12/45
# 35/35 - 10s - loss: 0.0627 - accuracy: 0.9920 - val_loss: 0.5773 - val_accuracy: 0.8286 - 10s/epoch - 283ms/step
# Epoch 13/45
# 35/35 - 10s - loss: 0.0478 - accuracy: 0.9955 - val_loss: 0.4999 - val_accuracy: 0.8393 - 10s/epoch - 282ms/step
# Epoch 14/45
# 35/35 - 10s - loss: 0.0401 - accuracy: 0.9973 - val_loss: 0.5278 - val_accuracy: 0.8357 - 10s/epoch - 293ms/step
# Epoch 15/45
# 35/35 - 10s - loss: 0.0382 - accuracy: 0.9973 - val_loss: 0.6837 - val_accuracy: 0.7964 - 10s/epoch - 299ms/step
# Epoch 16/45
# 35/35 - 10s - loss: 0.0263 - accuracy: 0.9991 - val_loss: 0.5604 - val_accuracy: 0.8357 - 10s/epoch - 292ms/step
# Epoch 17/45
# 35/35 - 10s - loss: 0.0177 - accuracy: 1.0000 - val_loss: 0.6314 - val_accuracy: 0.8286 - 10s/epoch - 294ms/step
# Epoch 18/45
# 35/35 - 10s - loss: 0.0141 - accuracy: 1.0000 - val_loss: 0.6092 - val_accuracy: 0.8357 - 10s/epoch - 280ms/step
# Epoch 19/45
# 35/35 - 10s - loss: 0.0116 - accuracy: 1.0000 - val_loss: 0.6007 - val_accuracy: 0.8464 - 10s/epoch - 299ms/step
# Epoch 20/45
# 35/35 - 10s - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.6356 - val_accuracy: 0.8286 - 10s/epoch - 299ms/step
# Epoch 21/45
# 35/35 - 11s - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.6205 - val_accuracy: 0.8393 - 11s/epoch - 311ms/step
# Epoch 22/45
# 35/35 - 11s - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.6760 - val_accuracy: 0.8321 - 11s/epoch - 302ms/step
# Epoch 23/45
# 35/35 - 11s - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.6498 - val_accuracy: 0.8393 - 11s/epoch - 303ms/step
# Epoch 24/45
# 35/35 - 10s - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.6959 - val_accuracy: 0.8286 - 10s/epoch - 297ms/step
# Epoch 25/45
# 35/35 - 11s - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.6777 - val_accuracy: 0.8321 - 11s/epoch - 308ms/step
# Epoch 26/45
# 35/35 - 10s - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.7025 - val_accuracy: 0.8321 - 10s/epoch - 297ms/step
# Epoch 27/45
# 35/35 - 10s - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.6829 - val_accuracy: 0.8357 - 10s/epoch - 296ms/step
# Epoch 28/45
# 35/35 - 10s - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.6763 - val_accuracy: 0.8429 - 10s/epoch - 298ms/step
# Epoch 29/45
# 35/35 - 10s - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.7417 - val_accuracy: 0.8250 - 10s/epoch - 283ms/step
# Epoch 30/45
# 35/35 - 10s - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.6979 - val_accuracy: 0.8464 - 10s/epoch - 278ms/step
# Epoch 31/45
# 35/35 - 10s - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.7100 - val_accuracy: 0.8357 - 10s/epoch - 291ms/step
# Epoch 32/45
# 35/35 - 10s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.7297 - val_accuracy: 0.8357 - 10s/epoch - 291ms/step
# Epoch 33/45
# 35/35 - 12s - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.7474 - val_accuracy: 0.8321 - 12s/epoch - 330ms/step
# Epoch 34/45
# 35/35 - 11s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.7206 - val_accuracy: 0.8393 - 11s/epoch - 324ms/step
# Epoch 35/45
# 35/35 - 11s - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.7459 - val_accuracy: 0.8321 - 11s/epoch - 320ms/step
# Epoch 36/45
# 35/35 - 11s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.7397 - val_accuracy: 0.8357 - 11s/epoch - 312ms/step
# Epoch 37/45
# 35/35 - 12s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.7550 - val_accuracy: 0.8321 - 12s/epoch - 351ms/step
# Epoch 38/45
# 35/35 - 13s - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.7822 - val_accuracy: 0.8321 - 13s/epoch - 366ms/step
# Epoch 39/45
# 35/35 - 12s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.7763 - val_accuracy: 0.8321 - 12s/epoch - 339ms/step
# Epoch 40/45
# 35/35 - 10s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.7626 - val_accuracy: 0.8321 - 10s/epoch - 295ms/step
# Epoch 41/45
# 35/35 - 12s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.7598 - val_accuracy: 0.8357 - 12s/epoch - 338ms/step
# Epoch 42/45
# 35/35 - 13s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.7652 - val_accuracy: 0.8357 - 13s/epoch - 383ms/step
# Epoch 43/45
# 35/35 - 11s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.7670 - val_accuracy: 0.8393 - 11s/epoch - 326ms/step
# Epoch 44/45
# 35/35 - 10s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.7777 - val_accuracy: 0.8357 - 10s/epoch - 296ms/step
# Epoch 45/45
# 35/35 - 10s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.7942 - val_accuracy: 0.8286 - 10s/epoch - 292ms/step
# 9/9 [==============================] - 2s 198ms/step - loss: 0.7942 - accuracy: 0.8286
#
#  Fold 1 - DenseNet Validation Accuracy: 0.8285714387893677
#
#
#  Fold 2
#
# Epoch 1/45
# 35/35 - 21s - loss: 0.7083 - acc: 0.5161 - val_loss: 0.6927 - val_acc: 0.5214 - 21s/epoch - 592ms/step
# Epoch 2/45
# 35/35 - 20s - loss: 0.6950 - acc: 0.5143 - val_loss: 0.6924 - val_acc: 0.4964 - 20s/epoch - 568ms/step
# Epoch 3/45
# 35/35 - 20s - loss: 0.6931 - acc: 0.5223 - val_loss: 0.6918 - val_acc: 0.5321 - 20s/epoch - 559ms/step
# Epoch 4/45
# 35/35 - 19s - loss: 0.6903 - acc: 0.5312 - val_loss: 0.6921 - val_acc: 0.5107 - 19s/epoch - 553ms/step
# Epoch 5/45
# 35/35 - 20s - loss: 0.6895 - acc: 0.5196 - val_loss: 0.6863 - val_acc: 0.5429 - 20s/epoch - 575ms/step
# Epoch 6/45
# 35/35 - 20s - loss: 0.6794 - acc: 0.5688 - val_loss: 0.6771 - val_acc: 0.6107 - 20s/epoch - 563ms/step
# Epoch 7/45
# 35/35 - 21s - loss: 0.6917 - acc: 0.5250 - val_loss: 0.6882 - val_acc: 0.5179 - 21s/epoch - 587ms/step
# Epoch 8/45
# 35/35 - 20s - loss: 0.6804 - acc: 0.5777 - val_loss: 0.6842 - val_acc: 0.5500 - 20s/epoch - 581ms/step
# Epoch 9/45
# 35/35 - 19s - loss: 0.6701 - acc: 0.5875 - val_loss: 0.6671 - val_acc: 0.6107 - 19s/epoch - 537ms/step
# Epoch 10/45
# 35/35 - 19s - loss: 0.6699 - acc: 0.5848 - val_loss: 0.6768 - val_acc: 0.5464 - 19s/epoch - 543ms/step
# Epoch 11/45
# 35/35 - 20s - loss: 0.6724 - acc: 0.5929 - val_loss: 0.6660 - val_acc: 0.6321 - 20s/epoch - 570ms/step
# Epoch 12/45
# 35/35 - 19s - loss: 0.6514 - acc: 0.5991 - val_loss: 0.6604 - val_acc: 0.6393 - 19s/epoch - 551ms/step
# Epoch 13/45
# 35/35 - 19s - loss: 0.6525 - acc: 0.5991 - val_loss: 0.6425 - val_acc: 0.6821 - 19s/epoch - 546ms/step
# Epoch 14/45
# 35/35 - 20s - loss: 0.6424 - acc: 0.6393 - val_loss: 0.6442 - val_acc: 0.6893 - 20s/epoch - 573ms/step
# Epoch 15/45
# 9/9 [==============================] - 3s 337ms/step - loss: 0.9493 - acc: 0.8107
#
#  Fold 2 - VGG16 Validation Accuracy: 0.8107143044471741
#
# Epoch 1/45
# 35/35 - 13s - loss: 0.7212 - accuracy: 0.4973 - val_loss: 0.6907 - val_accuracy: 0.5036 - 13s/epoch - 362ms/step
# Epoch 2/45
# 35/35 - 7s - loss: 0.6990 - accuracy: 0.4911 - val_loss: 0.6989 - val_accuracy: 0.4964 - 7s/epoch - 214ms/step
# Epoch 3/45
# 35/35 - 8s - loss: 0.6899 - accuracy: 0.5223 - val_loss: 0.6784 - val_accuracy: 0.5964 - 8s/epoch - 224ms/step
# Epoch 4/45
# 35/35 - 9s - loss: 0.6808 - accuracy: 0.5500 - val_loss: 0.6750 - val_accuracy: 0.6143 - 9s/epoch - 245ms/step
# Epoch 5/45
# 35/35 - 8s - loss: 0.6778 - accuracy: 0.5839 - val_loss: 0.6831 - val_accuracy: 0.5000 - 8s/epoch - 229ms/step
# Epoch 6/45
# 35/35 - 8s - loss: 0.6755 - accuracy: 0.5723 - val_loss: 0.6752 - val_accuracy: 0.5643 - 8s/epoch - 241ms/step
# Epoch 7/45
# 35/35 - 8s - loss: 0.6752 - accuracy: 0.5652 - val_loss: 0.6662 - val_accuracy: 0.6107 - 8s/epoch - 235ms/step
# Epoch 8/45
# 35/35 - 9s - loss: 0.6703 - accuracy: 0.5920 - val_loss: 0.6637 - val_accuracy: 0.6179 - 9s/epoch - 252ms/step
# Epoch 9/45
# 35/35 - 8s - loss: 0.6659 - accuracy: 0.6143 - val_loss: 0.6616 - val_accuracy: 0.5929 - 8s/epoch - 234ms/step
# Epoch 10/45
# 35/35 - 8s - loss: 0.6672 - accuracy: 0.6027 - val_loss: 0.6552 - val_accuracy: 0.6250 - 8s/epoch - 226ms/step
# Epoch 11/45
# 35/35 - 8s - loss: 0.6666 - accuracy: 0.5973 - val_loss: 0.6750 - val_accuracy: 0.5429 - 8s/epoch - 230ms/step
# Epoch 12/45
# 35/35 - 8s - loss: 0.6610 - accuracy: 0.6107 - val_loss: 0.6727 - val_accuracy: 0.5679 - 8s/epoch - 222ms/step
# Epoch 13/45
# 35/35 - 8s - loss: 0.6667 - accuracy: 0.6045 - val_loss: 0.6491 - val_accuracy: 0.6179 - 8s/epoch - 232ms/step
# Epoch 14/45
# 35/35 - 8s - loss: 0.6594 - accuracy: 0.6214 - val_loss: 0.6519 - val_accuracy: 0.6250 - 8s/epoch - 225ms/step
# Epoch 15/45
# 35/35 - 9s - loss: 0.6603 - accuracy: 0.6134 - val_loss: 0.6511 - val_accuracy: 0.6250 - 9s/epoch - 246ms/step
# Epoch 16/45
# 35/35 - 8s - loss: 0.6534 - accuracy: 0.6402 - val_loss: 0.6455 - val_accuracy: 0.6250 - 8s/epoch - 226ms/step
# Epoch 17/45
# 35/35 - 8s - loss: 0.6553 - accuracy: 0.6125 - val_loss: 0.6431 - val_accuracy: 0.6393 - 8s/epoch - 230ms/step
# Epoch 18/45
# 35/35 - 8s - loss: 0.6573 - accuracy: 0.6187 - val_loss: 0.6616 - val_accuracy: 0.6143 - 8s/epoch - 222ms/step
# Epoch 19/45
# 35/35 - 8s - loss: 0.6572 - accuracy: 0.5938 - val_loss: 0.6456 - val_accuracy: 0.6250 - 8s/epoch - 238ms/step
# Epoch 20/45
# 35/35 - 8s - loss: 0.6561 - accuracy: 0.6125 - val_loss: 0.6448 - val_accuracy: 0.6250 - 8s/epoch - 223ms/step
# Epoch 21/45
# 35/35 - 8s - loss: 0.6500 - accuracy: 0.6259 - val_loss: 0.6534 - val_accuracy: 0.6143 - 8s/epoch - 237ms/step
# Epoch 22/45
# 35/35 - 8s - loss: 0.6470 - accuracy: 0.6339 - val_loss: 0.6379 - val_accuracy: 0.6429 - 8s/epoch - 236ms/step
# Epoch 23/45
# 35/35 - 9s - loss: 0.6463 - accuracy: 0.6339 - val_loss: 0.6404 - val_accuracy: 0.6286 - 9s/epoch - 260ms/step
# Epoch 24/45
# 35/35 - 8s - loss: 0.6520 - accuracy: 0.6286 - val_loss: 0.6352 - val_accuracy: 0.6429 - 8s/epoch - 227ms/step
# Epoch 25/45
# 35/35 - 9s - loss: 0.6435 - accuracy: 0.6268 - val_loss: 0.6409 - val_accuracy: 0.6321 - 9s/epoch - 244ms/step
# Epoch 26/45
# 35/35 - 8s - loss: 0.6431 - accuracy: 0.6509 - val_loss: 0.6372 - val_accuracy: 0.6250 - 8s/epoch - 227ms/step
# Epoch 27/45
# 35/35 - 9s - loss: 0.6463 - accuracy: 0.6232 - val_loss: 0.6323 - val_accuracy: 0.6643 - 9s/epoch - 248ms/step
# Epoch 28/45
# 35/35 - 8s - loss: 0.6437 - accuracy: 0.6384 - val_loss: 0.6377 - val_accuracy: 0.6250 - 8s/epoch - 230ms/step
# Epoch 29/45
# 35/35 - 8s - loss: 0.6493 - accuracy: 0.6348 - val_loss: 0.6406 - val_accuracy: 0.6321 - 8s/epoch - 240ms/step
# Epoch 30/45
# 35/35 - 8s - loss: 0.6479 - accuracy: 0.6179 - val_loss: 0.6399 - val_accuracy: 0.6357 - 8s/epoch - 242ms/step
# Epoch 31/45
# 35/35 - 8s - loss: 0.6439 - accuracy: 0.6384 - val_loss: 0.6293 - val_accuracy: 0.6607 - 8s/epoch - 241ms/step
# Epoch 32/45
# 35/35 - 8s - loss: 0.6415 - accuracy: 0.6384 - val_loss: 0.6318 - val_accuracy: 0.6321 - 8s/epoch - 219ms/step
# Epoch 33/45
# 35/35 - 8s - loss: 0.6462 - accuracy: 0.6420 - val_loss: 0.6288 - val_accuracy: 0.6607 - 8s/epoch - 238ms/step
# Epoch 34/45
# 35/35 - 8s - loss: 0.6405 - accuracy: 0.6411 - val_loss: 0.6273 - val_accuracy: 0.6607 - 8s/epoch - 216ms/step
# Epoch 35/45
# 35/35 - 8s - loss: 0.6370 - accuracy: 0.6339 - val_loss: 0.6280 - val_accuracy: 0.6536 - 8s/epoch - 238ms/step
# Epoch 36/45
# 35/35 - 8s - loss: 0.6351 - accuracy: 0.6295 - val_loss: 0.6266 - val_accuracy: 0.6643 - 8s/epoch - 218ms/step
# Epoch 37/45
# 35/35 - 9s - loss: 0.6430 - accuracy: 0.6304 - val_loss: 0.6405 - val_accuracy: 0.6286 - 9s/epoch - 253ms/step
# Epoch 38/45
# 35/35 - 8s - loss: 0.6337 - accuracy: 0.6473 - val_loss: 0.6343 - val_accuracy: 0.6321 - 8s/epoch - 218ms/step
# Epoch 39/45
# 35/35 - 9s - loss: 0.6351 - accuracy: 0.6393 - val_loss: 0.6242 - val_accuracy: 0.6750 - 9s/epoch - 244ms/step
# Epoch 40/45
# 35/35 - 8s - loss: 0.6333 - accuracy: 0.6446 - val_loss: 0.6253 - val_accuracy: 0.6714 - 8s/epoch - 223ms/step
# Epoch 41/45
# 35/35 - 8s - loss: 0.6350 - accuracy: 0.6420 - val_loss: 0.6257 - val_accuracy: 0.6464 - 8s/epoch - 240ms/step
# Epoch 42/45
# 35/35 - 8s - loss: 0.6322 - accuracy: 0.6482 - val_loss: 0.6220 - val_accuracy: 0.6607 - 8s/epoch - 221ms/step
# Epoch 43/45
# 35/35 - 8s - loss: 0.6331 - accuracy: 0.6473 - val_loss: 0.6238 - val_accuracy: 0.6536 - 8s/epoch - 242ms/step
# Epoch 44/45
# 35/35 - 8s - loss: 0.6308 - accuracy: 0.6366 - val_loss: 0.6227 - val_accuracy: 0.6786 - 8s/epoch - 242ms/step
# Epoch 45/45
# 35/35 - 8s - loss: 0.6308 - accuracy: 0.6473 - val_loss: 0.6218 - val_accuracy: 0.6786 - 8s/epoch - 241ms/step
# 9/9 [==============================] - 2s 168ms/step - loss: 0.6218 - accuracy: 0.6786
#
#  Fold 2 - ResNet Validation Accuracy: 0.6785714030265808
#
# Epoch 1/45
# 35/35 - 23s - loss: 1.2609 - accuracy: 0.6375 - val_loss: 0.6145 - val_accuracy: 0.6821 - 23s/epoch - 656ms/step
# Epoch 2/45
# 35/35 - 9s - loss: 0.5270 - accuracy: 0.7339 - val_loss: 0.5749 - val_accuracy: 0.7179 - 9s/epoch - 253ms/step
# Epoch 3/45
# 35/35 - 11s - loss: 0.4450 - accuracy: 0.7946 - val_loss: 0.5115 - val_accuracy: 0.7643 - 11s/epoch - 324ms/step
# Epoch 4/45
# 35/35 - 11s - loss: 0.3790 - accuracy: 0.8196 - val_loss: 0.5300 - val_accuracy: 0.7786 - 11s/epoch - 327ms/step
# Epoch 5/45
# 35/35 - 11s - loss: 0.3193 - accuracy: 0.8643 - val_loss: 0.5271 - val_accuracy: 0.7929 - 11s/epoch - 310ms/step
# Epoch 6/45
# 35/35 - 11s - loss: 0.2759 - accuracy: 0.8964 - val_loss: 0.5469 - val_accuracy: 0.7679 - 11s/epoch - 309ms/step
# Epoch 7/45
# 35/35 - 11s - loss: 0.2059 - accuracy: 0.9312 - val_loss: 0.5583 - val_accuracy: 0.7964 - 11s/epoch - 317ms/step
# Epoch 8/45
# 35/35 - 11s - loss: 0.1847 - accuracy: 0.9420 - val_loss: 0.5731 - val_accuracy: 0.7964 - 11s/epoch - 318ms/step
# Epoch 9/45
# 35/35 - 11s - loss: 0.1512 - accuracy: 0.9545 - val_loss: 0.5759 - val_accuracy: 0.8250 - 11s/epoch - 328ms/step
# Epoch 10/45
# 35/35 - 11s - loss: 0.1079 - accuracy: 0.9768 - val_loss: 0.6677 - val_accuracy: 0.8000 - 11s/epoch - 325ms/step
# Epoch 11/45
# 35/35 - 11s - loss: 0.0813 - accuracy: 0.9902 - val_loss: 0.6289 - val_accuracy: 0.8250 - 11s/epoch - 325ms/step
# Epoch 12/45
# 35/35 - 11s - loss: 0.0616 - accuracy: 0.9911 - val_loss: 0.6702 - val_accuracy: 0.8393 - 11s/epoch - 312ms/step
# Epoch 13/45
# 35/35 - 11s - loss: 0.0516 - accuracy: 0.9955 - val_loss: 0.6979 - val_accuracy: 0.8321 - 11s/epoch - 326ms/step
# Epoch 14/45
# 35/35 - 12s - loss: 0.0365 - accuracy: 0.9973 - val_loss: 0.7120 - val_accuracy: 0.8250 - 12s/epoch - 332ms/step
# Epoch 15/45
# 35/35 - 11s - loss: 0.0267 - accuracy: 1.0000 - val_loss: 0.7649 - val_accuracy: 0.8321 - 11s/epoch - 319ms/step
# Epoch 16/45
# 35/35 - 11s - loss: 0.0222 - accuracy: 1.0000 - val_loss: 0.7521 - val_accuracy: 0.8393 - 11s/epoch - 302ms/step
# Epoch 17/45
# 35/35 - 11s - loss: 0.0171 - accuracy: 1.0000 - val_loss: 0.8061 - val_accuracy: 0.8286 - 11s/epoch - 313ms/step
# Epoch 18/45
# 35/35 - 11s - loss: 0.0132 - accuracy: 1.0000 - val_loss: 0.8085 - val_accuracy: 0.8321 - 11s/epoch - 316ms/step
# Epoch 19/45
# 35/35 - 11s - loss: 0.0121 - accuracy: 1.0000 - val_loss: 0.8484 - val_accuracy: 0.8286 - 11s/epoch - 301ms/step
# Epoch 20/45
# 35/35 - 12s - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.8495 - val_accuracy: 0.8250 - 12s/epoch - 334ms/step
# Epoch 21/45
# 35/35 - 11s - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.8790 - val_accuracy: 0.8214 - 11s/epoch - 320ms/step
# Epoch 22/45
# 35/35 - 11s - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.8700 - val_accuracy: 0.8286 - 11s/epoch - 309ms/step
# Epoch 23/45
# 35/35 - 11s - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.8947 - val_accuracy: 0.8286 - 11s/epoch - 324ms/step
# Epoch 24/45
# 35/35 - 11s - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.9426 - val_accuracy: 0.8250 - 11s/epoch - 323ms/step
# Epoch 25/45
# 35/35 - 12s - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.9084 - val_accuracy: 0.8286 - 12s/epoch - 332ms/step
# Epoch 26/45
# 35/35 - 13s - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.9476 - val_accuracy: 0.8321 - 13s/epoch - 358ms/step
# Epoch 27/45
# 35/35 - 12s - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.9441 - val_accuracy: 0.8357 - 12s/epoch - 338ms/step
# Epoch 28/45
# 35/35 - 12s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.9521 - val_accuracy: 0.8321 - 12s/epoch - 333ms/step
# Epoch 29/45
# 35/35 - 11s - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.9547 - val_accuracy: 0.8393 - 11s/epoch - 323ms/step
# Epoch 30/45
# 35/35 - 13s - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.9773 - val_accuracy: 0.8321 - 13s/epoch - 357ms/step
# Epoch 31/45
# 35/35 - 13s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.9948 - val_accuracy: 0.8321 - 13s/epoch - 370ms/step
# Epoch 32/45
# 35/35 - 12s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.9981 - val_accuracy: 0.8357 - 12s/epoch - 338ms/step
# Epoch 33/45
# 35/35 - 12s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.0018 - val_accuracy: 0.8321 - 12s/epoch - 337ms/step
# Epoch 34/45
# 35/35 - 11s - loss: 0.0022 - accuracy: 1.0000 - val_loss: 1.0199 - val_accuracy: 0.8286 - 11s/epoch - 314ms/step
# Epoch 35/45
# 35/35 - 12s - loss: 0.0021 - accuracy: 1.0000 - val_loss: 1.0405 - val_accuracy: 0.8250 - 12s/epoch - 334ms/step
# Epoch 36/45
# 35/35 - 11s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.0428 - val_accuracy: 0.8357 - 11s/epoch - 317ms/step
# Epoch 37/45
# 35/35 - 11s - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.0388 - val_accuracy: 0.8357 - 11s/epoch - 304ms/step
# Epoch 38/45
# 35/35 - 11s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.0561 - val_accuracy: 0.8286 - 11s/epoch - 316ms/step
# Epoch 39/45
# 35/35 - 11s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.0538 - val_accuracy: 0.8357 - 11s/epoch - 313ms/step
# Epoch 40/45
# 35/35 - 11s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.0638 - val_accuracy: 0.8357 - 11s/epoch - 316ms/step
# Epoch 41/45
# 35/35 - 11s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.0674 - val_accuracy: 0.8357 - 11s/epoch - 320ms/step
# Epoch 42/45
# 35/35 - 11s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.0820 - val_accuracy: 0.8357 - 11s/epoch - 315ms/step
# Epoch 43/45
# 35/35 - 11s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.0819 - val_accuracy: 0.8321 - 11s/epoch - 311ms/step
# Epoch 44/45
# 35/35 - 12s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.0948 - val_accuracy: 0.8357 - 12s/epoch - 337ms/step
# Epoch 45/45
# 35/35 - 13s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.0970 - val_accuracy: 0.8321 - 13s/epoch - 369ms/step
# 9/9 [==============================] - 3s 293ms/step - loss: 1.0970 - accuracy: 0.8321
#
#  Fold 2 - DenseNet Validation Accuracy: 0.8321428298950195
#
#
#  Fold 3
#
# Epoch 1/45
# 35/35 - 22s - loss: 0.7219 - acc: 0.4929 - val_loss: 0.6935 - val_acc: 0.4821 - 22s/epoch - 637ms/step
# Epoch 2/45
# 35/35 - 20s - loss: 0.6917 - acc: 0.5036 - val_loss: 0.6943 - val_acc: 0.4821 - 20s/epoch - 583ms/step
# Epoch 3/45
# 35/35 - 21s - loss: 0.6940 - acc: 0.5232 - val_loss: 0.6929 - val_acc: 0.4821 - 21s/epoch - 587ms/step
# Epoch 4/45
# 35/35 - 20s - loss: 0.6947 - acc: 0.5071 - val_loss: 0.6917 - val_acc: 0.5179 - 20s/epoch - 560ms/step
# Epoch 5/45
# 35/35 - 19s - loss: 0.6930 - acc: 0.5179 - val_loss: 0.6958 - val_acc: 0.4857 - 19s/epoch - 544ms/step
# Epoch 6/45
# 35/35 - 19s - loss: 0.6903 - acc: 0.5268 - val_loss: 0.6888 - val_acc: 0.4893 - 19s/epoch - 554ms/step
# Epoch 7/45
# 35/35 - 19s - loss: 0.6821 - acc: 0.5571 - val_loss: 0.6875 - val_acc: 0.5464 - 19s/epoch - 553ms/step
# Epoch 8/45
# 35/35 - 19s - loss: 0.6905 - acc: 0.5402 - val_loss: 0.6890 - val_acc: 0.5179 - 19s/epoch - 551ms/step
# Epoch 9/45
# 35/35 - 20s - loss: 0.6790 - acc: 0.5759 - val_loss: 0.6870 - val_acc: 0.5571 - 20s/epoch - 571ms/step
# Epoch 10/45
# 35/35 - 21s - loss: 0.6734 - acc: 0.5848 - val_loss: 0.6886 - val_acc: 0.5321 - 21s/epoch - 587ms/step
# Epoch 11/45
# 35/35 - 21s - loss: 0.5776 - acc: 0.6884 - val_loss: 0.6306 - val_acc: 0.6357 - 21s/epoch - 594ms/step
# Epoch 31/45
# 35/35 - 20s - loss: 0.5838 - acc: 0.6839 - val_loss: 0.6313 - val_acc: 0.6321 - 20s/epoch - 571ms/step
# Epoch 32/45
# 35/35 - 19s - loss: 0.5598 - acc: 0.6973 - val_loss: 0.6200 - val_acc: 0.6464 - 19s/epoch - 556ms/step
# Epoch 33/45
# 35/35 - 21s - loss: 0.5516 - acc: 0.7196 - val_loss: 0.6227 - val_acc: 0.6571 - 21s/epoch - 587ms/step
# Epoch 34/45
# ...
# Epoch 38/50
# 18/18 - 17s - loss: 0.0571 - acc: 0.9911 - val_loss: 0.1273 - val_acc: 0.9640 - 17s/epoch - 931ms/step
# Epoch 39/50
# 18/18 - 16s - loss: 0.0617 - acc: 0.9875 - val_loss: 0.1434 - val_acc: 0.9640 - 16s/epoch - 903ms/step
# Epoch 40/50
# 18/18 - 16s - loss: 0.0463 - acc: 0.9964 - val_loss: 0.1402 - val_acc: 0.9640 - 16s/epoch - 905ms/step
# Epoch 41/50
# 18/18 - 17s - loss: 0.0544 - acc: 0.9839 - val_loss: 0.1200 - val_acc: 0.9712 - 17s/epoch - 919ms/step
# Epoch 42/50
# 18/18 - 16s - loss: 0.0408 - acc: 0.9964 - val_loss: 0.1247 - val_acc: 0.9712 - 16s/epoch - 882ms/step
# Epoch 43/50
# 18/18 - 16s - loss: 0.0438 - acc: 0.9911 - val_loss: 0.1274 - val_acc: 0.9712 - 16s/epoch - 884ms/step
# Epoch 44/50
# 18/18 - 16s - loss: 0.0575 - acc: 0.9857 - val_loss: 0.1069 - val_acc: 0.9712 - 16s/epoch - 890ms/step
# Epoch 45/50
# 18/18 - 18s - loss: 0.0372 - acc: 0.9964 - val_loss: 0.1151 - val_acc: 0.9712 - 18s/epoch - 982ms/step
# Epoch 46/50
# 18/18 - 16s - loss: 0.0341 - acc: 0.9964 - val_loss: 0.1120 - val_acc: 0.9712 - 16s/epoch - 883ms/step
# Epoch 47/50
# 18/18 - 17s - loss: 0.0359 - acc: 0.9946 - val_loss: 0.1148 - val_acc: 0.9712 - 17s/epoch - 934ms/step
# Epoch 48/50
# 18/18 - 17s - loss: 0.0372 - acc: 0.9929 - val_loss: 0.1165 - val_acc: 0.9712 - 17s/epoch - 954ms/step
# Epoch 49/50
# 18/18 - 18s - loss: 0.0277 - acc: 0.9982 - val_loss: 0.1152 - val_acc: 0.9712 - 18s/epoch - 1s/step
# Epoch 50/50
# 18/18 - 16s - loss: 0.0289 - acc: 0.9964 - val_loss: 0.1157 - val_acc: 0.9712 - 16s/epoch - 903ms/step
# 5/5 [==============================] - 4s 681ms/step - loss: 0.1157 - acc: 0.9712
#
#  Fold 5 - VGG16 Validation Accuracy: 0.971222996711731
#
# Epoch 1/50
# 18/18 - 18s - loss: 0.6853 - accuracy: 0.5875 - val_loss: 0.6590 - val_accuracy: 0.6259 - 18s/epoch - 1s/step
# Epoch 2/50
# 18/18 - 11s - loss: 0.6604 - accuracy: 0.6071 - val_loss: 0.6448 - val_accuracy: 0.6259 - 11s/epoch - 624ms/step
# Epoch 3/50
# 18/18 - 11s - loss: 0.6547 - accuracy: 0.6071 - val_loss: 0.6376 - val_accuracy: 0.6259 - 11s/epoch - 617ms/step
# Epoch 4/50
# 18/18 - 12s - loss: 0.6471 - accuracy: 0.6071 - val_loss: 0.6281 - val_accuracy: 0.6259 - 12s/epoch - 666ms/step
# Epoch 5/50
# 18/18 - 11s - loss: 0.6409 - accuracy: 0.6071 - val_loss: 0.6206 - val_accuracy: 0.6259 - 11s/epoch - 590ms/step
# Epoch 6/50
# 18/18 - 11s - loss: 0.6364 - accuracy: 0.6089 - val_loss: 0.6203 - val_accuracy: 0.6331 - 11s/epoch - 615ms/step
# Epoch 7/50
# 18/18 - 11s - loss: 0.6328 - accuracy: 0.6071 - val_loss: 0.6087 - val_accuracy: 0.6259 - 11s/epoch - 613ms/step
# Epoch 8/50
# 18/18 - 12s - loss: 0.6275 - accuracy: 0.6125 - val_loss: 0.6043 - val_accuracy: 0.6187 - 12s/epoch - 653ms/step
# Epoch 9/50
# 18/18 - 12s - loss: 0.6264 - accuracy: 0.6179 - val_loss: 0.6018 - val_accuracy: 0.6547 - 12s/epoch - 678ms/step
# Epoch 10/50
# 18/18 - 12s - loss: 0.6236 - accuracy: 0.6036 - val_loss: 0.5954 - val_accuracy: 0.6403 - 12s/epoch - 652ms/step
# Epoch 11/50
# 18/18 - 12s - loss: 0.6202 - accuracy: 0.6143 - val_loss: 0.5927 - val_accuracy: 0.6619 - 12s/epoch - 665ms/step
# Epoch 12/50
# 18/18 - 11s - loss: 0.6193 - accuracy: 0.6268 - val_loss: 0.5881 - val_accuracy: 0.6187 - 11s/epoch - 614ms/step
# Epoch 13/50
# 18/18 - 12s - loss: 0.6165 - accuracy: 0.6161 - val_loss: 0.5869 - val_accuracy: 0.6906 - 12s/epoch - 661ms/step
# Epoch 14/50
# 18/18 - 12s - loss: 0.6136 - accuracy: 0.6732 - val_loss: 0.5826 - val_accuracy: 0.6475 - 12s/epoch - 681ms/step
# Epoch 15/50
# 18/18 - 12s - loss: 0.6131 - accuracy: 0.6375 - val_loss: 0.5806 - val_accuracy: 0.6547 - 12s/epoch - 670ms/step
# Epoch 16/50
# 18/18 - 12s - loss: 0.6170 - accuracy: 0.6214 - val_loss: 0.5774 - val_accuracy: 0.6691 - 12s/epoch - 649ms/step
# Epoch 17/50
# 18/18 - 11s - loss: 0.6174 - accuracy: 0.6536 - val_loss: 0.5771 - val_accuracy: 0.6547 - 11s/epoch - 616ms/step
# Epoch 18/50
# 18/18 - 12s - loss: 0.6090 - accuracy: 0.6446 - val_loss: 0.5734 - val_accuracy: 0.6763 - 12s/epoch - 671ms/step
# Epoch 19/50
# 18/18 - 12s - loss: 0.6069 - accuracy: 0.6643 - val_loss: 0.5721 - val_accuracy: 0.6547 - 12s/epoch - 652ms/step
# Epoch 20/50
# 18/18 - 12s - loss: 0.6058 - accuracy: 0.6500 - val_loss: 0.5705 - val_accuracy: 0.7266 - 12s/epoch - 647ms/step
# Epoch 21/50
# 18/18 - 12s - loss: 0.6066 - accuracy: 0.6625 - val_loss: 0.5700 - val_accuracy: 0.6547 - 12s/epoch - 657ms/step
# Epoch 22/50
# 18/18 - 11s - loss: 0.6026 - accuracy: 0.6607 - val_loss: 0.5681 - val_accuracy: 0.7194 - 11s/epoch - 587ms/step
# Epoch 23/50
# 18/18 - 12s - loss: 0.6058 - accuracy: 0.6393 - val_loss: 0.5712 - val_accuracy: 0.7194 - 12s/epoch - 640ms/step
# Epoch 24/50
# 18/18 - 12s - loss: 0.6034 - accuracy: 0.6661 - val_loss: 0.5649 - val_accuracy: 0.6619 - 12s/epoch - 664ms/step
# Epoch 25/50
# 18/18 - 12s - loss: 0.6013 - accuracy: 0.6500 - val_loss: 0.5641 - val_accuracy: 0.7194 - 12s/epoch - 657ms/step
# Epoch 26/50
# 18/18 - 12s - loss: 0.6011 - accuracy: 0.6607 - val_loss: 0.5660 - val_accuracy: 0.7338 - 12s/epoch - 675ms/step
# Epoch 27/50
# 18/18 - 11s - loss: 0.6016 - accuracy: 0.6696 - val_loss: 0.5640 - val_accuracy: 0.6547 - 11s/epoch - 638ms/step
# Epoch 28/50
# 18/18 - 11s - loss: 0.5962 - accuracy: 0.6464 - val_loss: 0.5728 - val_accuracy: 0.6906 - 11s/epoch - 630ms/step
# Epoch 29/50
# 18/18 - 12s - loss: 0.6064 - accuracy: 0.6464 - val_loss: 0.5620 - val_accuracy: 0.6547 - 12s/epoch - 686ms/step
# Epoch 30/50
# 18/18 - 12s - loss: 0.5995 - accuracy: 0.6661 - val_loss: 0.5582 - val_accuracy: 0.7338 - 12s/epoch - 640ms/step
# Epoch 31/50
# 18/18 - 12s - loss: 0.5994 - accuracy: 0.6607 - val_loss: 0.5638 - val_accuracy: 0.6978 - 12s/epoch - 668ms/step
# Epoch 32/50
# 18/18 - 11s - loss: 0.5993 - accuracy: 0.6714 - val_loss: 0.5562 - val_accuracy: 0.7338 - 11s/epoch - 626ms/step
# Epoch 33/50
# 18/18 - 11s - loss: 0.5955 - accuracy: 0.6768 - val_loss: 0.5560 - val_accuracy: 0.7266 - 11s/epoch - 607ms/step
# Epoch 34/50
# 18/18 - 11s - loss: 0.5931 - accuracy: 0.6804 - val_loss: 0.5576 - val_accuracy: 0.6763 - 11s/epoch - 629ms/step
# Epoch 35/50
# 18/18 - 12s - loss: 0.6072 - accuracy: 0.6411 - val_loss: 0.5726 - val_accuracy: 0.6978 - 12s/epoch - 643ms/step
# Epoch 36/50
# 18/18 - 12s - loss: 0.6089 - accuracy: 0.6321 - val_loss: 0.5553 - val_accuracy: 0.6691 - 12s/epoch - 669ms/step
# Epoch 37/50
# 18/18 - 12s - loss: 0.5931 - accuracy: 0.6804 - val_loss: 0.5537 - val_accuracy: 0.6978 - 12s/epoch - 661ms/step
# Epoch 38/50
# 18/18 - 12s - loss: 0.6089 - accuracy: 0.6482 - val_loss: 0.5631 - val_accuracy: 0.7050 - 12s/epoch - 645ms/step
# Epoch 39/50
# 18/18 - 12s - loss: 0.5988 - accuracy: 0.6750 - val_loss: 0.5524 - val_accuracy: 0.7194 - 12s/epoch - 656ms/step
# Epoch 40/50
# 18/18 - 12s - loss: 0.5921 - accuracy: 0.6750 - val_loss: 0.5507 - val_accuracy: 0.7554 - 12s/epoch - 674ms/step
# Epoch 41/50
# 18/18 - 11s - loss: 0.5872 - accuracy: 0.6821 - val_loss: 0.5512 - val_accuracy: 0.7194 - 11s/epoch - 623ms/step
# Epoch 42/50
# 18/18 - 12s - loss: 0.5918 - accuracy: 0.6696 - val_loss: 0.5495 - val_accuracy: 0.7482 - 12s/epoch - 648ms/step
# Epoch 43/50
# 18/18 - 11s - loss: 0.5878 - accuracy: 0.6804 - val_loss: 0.5490 - val_accuracy: 0.7482 - 11s/epoch - 612ms/step
# Epoch 44/50
# 18/18 - 11s - loss: 0.5872 - accuracy: 0.6821 - val_loss: 0.5483 - val_accuracy: 0.7410 - 11s/epoch - 599ms/step
# Epoch 45/50
# 18/18 - 12s - loss: 0.5877 - accuracy: 0.6768 - val_loss: 0.5488 - val_accuracy: 0.7338 - 12s/epoch - 674ms/step
# Epoch 46/50
# 18/18 - 10s - loss: 0.5874 - accuracy: 0.6625 - val_loss: 0.5502 - val_accuracy: 0.7266 - 10s/epoch - 553ms/step
# Epoch 47/50
# 18/18 - 12s - loss: 0.5907 - accuracy: 0.6732 - val_loss: 0.5598 - val_accuracy: 0.6691 - 12s/epoch - 652ms/step
# Epoch 48/50
# 18/18 - 11s - loss: 0.5926 - accuracy: 0.6714 - val_loss: 0.5467 - val_accuracy: 0.7410 - 11s/epoch - 613ms/step
# Epoch 49/50
# 18/18 - 12s - loss: 0.5841 - accuracy: 0.6804 - val_loss: 0.5482 - val_accuracy: 0.6978 - 12s/epoch - 645ms/step
# Epoch 50/50
# 18/18 - 12s - loss: 0.5839 - accuracy: 0.6786 - val_loss: 0.5465 - val_accuracy: 0.7266 - 12s/epoch - 651ms/step
# 5/5 [==============================] - 3s 517ms/step - loss: 0.5465 - accuracy: 0.7266
#
#  Fold 5 - ResNet Validation Accuracy: 0.7266187071800232
#
# Epoch 1/50
# 18/18 - 22s - loss: 1.6224 - accuracy: 0.6554 - val_loss: 0.4895 - val_accuracy: 0.7842 - 22s/epoch - 1s/step
# Epoch 2/50
# 18/18 - 10s - loss: 0.3350 - accuracy: 0.8482 - val_loss: 0.2705 - val_accuracy: 0.8849 - 10s/epoch - 535ms/step
# Epoch 3/50
# 18/18 - 10s - loss: 0.2212 - accuracy: 0.9107 - val_loss: 0.2345 - val_accuracy: 0.8849 - 10s/epoch - 533ms/step
# Epoch 4/50
# 18/18 - 10s - loss: 0.1612 - accuracy: 0.9393 - val_loss: 0.1736 - val_accuracy: 0.9353 - 10s/epoch - 529ms/step
# Epoch 5/50
# 18/18 - 9s - loss: 0.1124 - accuracy: 0.9643 - val_loss: 0.2013 - val_accuracy: 0.9137 - 9s/epoch - 520ms/step
# Epoch 6/50
# 18/18 - 9s - loss: 0.0776 - accuracy: 0.9839 - val_loss: 0.1505 - val_accuracy: 0.9568 - 9s/epoch - 524ms/step
# Epoch 7/50
# 18/18 - 10s - loss: 0.0449 - accuracy: 0.9964 - val_loss: 0.1507 - val_accuracy: 0.9353 - 10s/epoch - 533ms/step
# Epoch 8/50
# 18/18 - 11s - loss: 0.0306 - accuracy: 1.0000 - val_loss: 0.1331 - val_accuracy: 0.9424 - 11s/epoch - 621ms/step
# Epoch 9/50
# 18/18 - 10s - loss: 0.0231 - accuracy: 1.0000 - val_loss: 0.1441 - val_accuracy: 0.9424 - 10s/epoch - 541ms/step
# Epoch 10/50
# 18/18 - 11s - loss: 0.0146 - accuracy: 1.0000 - val_loss: 0.1461 - val_accuracy: 0.9424 - 11s/epoch - 588ms/step
# Epoch 11/50
# 18/18 - 10s - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.1518 - val_accuracy: 0.9281 - 10s/epoch - 577ms/step
# Epoch 12/50
# 18/18 - 10s - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.1506 - val_accuracy: 0.9281 - 10s/epoch - 534ms/step
# Epoch 13/50
# 18/18 - 10s - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.1492 - val_accuracy: 0.9281 - 10s/epoch - 532ms/step
# Epoch 14/50
# 18/18 - 11s - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.1576 - val_accuracy: 0.9281 - 11s/epoch - 602ms/step
# Epoch 15/50
# 18/18 - 10s - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.1678 - val_accuracy: 0.9065 - 10s/epoch - 541ms/step
# Epoch 16/50
# 18/18 - 10s - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.1686 - val_accuracy: 0.9209 - 10s/epoch - 540ms/step
# Epoch 17/50
# 18/18 - 10s - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.1673 - val_accuracy: 0.9281 - 10s/epoch - 537ms/step
# Epoch 18/50
# 18/18 - 10s - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.1712 - val_accuracy: 0.9281 - 10s/epoch - 535ms/step
# Epoch 19/50
# 18/18 - 10s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1743 - val_accuracy: 0.9209 - 10s/epoch - 533ms/step
# Epoch 20/50
# 18/18 - 10s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1661 - val_accuracy: 0.9281 - 10s/epoch - 563ms/step
# Epoch 21/50
# 18/18 - 10s - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1774 - val_accuracy: 0.9209 - 10s/epoch - 545ms/step
# Epoch 22/50
# 18/18 - 10s - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1746 - val_accuracy: 0.9209 - 10s/epoch - 535ms/step
# Epoch 23/50
# 18/18 - 10s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1803 - val_accuracy: 0.9209 - 10s/epoch - 531ms/step
# Epoch 24/50
# 18/18 - 10s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1822 - val_accuracy: 0.9209 - 10s/epoch - 531ms/step
# Epoch 25/50
# 18/18 - 10s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1842 - val_accuracy: 0.9209 - 10s/epoch - 536ms/step
# Epoch 26/50
# 18/18 - 10s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1889 - val_accuracy: 0.9209 - 10s/epoch - 568ms/step
# Epoch 27/50
# 18/18 - 10s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1913 - val_accuracy: 0.9209 - 10s/epoch - 542ms/step
# Epoch 28/50
# 18/18 - 10s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1877 - val_accuracy: 0.9209 - 10s/epoch - 566ms/step
# Epoch 29/50
# 18/18 - 10s - loss: 9.5942e-04 - accuracy: 1.0000 - val_loss: 0.1929 - val_accuracy: 0.9209 - 10s/epoch - 535ms/step
# Epoch 30/50
# 18/18 - 10s - loss: 8.8128e-04 - accuracy: 1.0000 - val_loss: 0.1903 - val_accuracy: 0.9209 - 10s/epoch - 534ms/step
# Epoch 31/50
# 18/18 - 11s - loss: 8.2595e-04 - accuracy: 1.0000 - val_loss: 0.1935 - val_accuracy: 0.9209 - 11s/epoch - 588ms/step
# Epoch 32/50
# 18/18 - 11s - loss: 7.6504e-04 - accuracy: 1.0000 - val_loss: 0.1972 - val_accuracy: 0.9209 - 11s/epoch - 616ms/step
# Epoch 33/50
# 18/18 - 10s - loss: 7.2681e-04 - accuracy: 1.0000 - val_loss: 0.1995 - val_accuracy: 0.9209 - 10s/epoch - 557ms/step
# Epoch 34/50
# 18/18 - 13s - loss: 6.8050e-04 - accuracy: 1.0000 - val_loss: 0.1966 - val_accuracy: 0.9209 - 13s/epoch - 734ms/step
# Epoch 35/50
# 18/18 - 11s - loss: 6.2332e-04 - accuracy: 1.0000 - val_loss: 0.2008 - val_accuracy: 0.9209 - 11s/epoch - 601ms/step
# Epoch 36/50
# 18/18 - 10s - loss: 5.8907e-04 - accuracy: 1.0000 - val_loss: 0.1992 - val_accuracy: 0.9209 - 10s/epoch - 560ms/step
# Epoch 37/50
# 18/18 - 10s - loss: 5.5456e-04 - accuracy: 1.0000 - val_loss: 0.2030 - val_accuracy: 0.9209 - 10s/epoch - 563ms/step
# Epoch 38/50
# 18/18 - 11s - loss: 5.2338e-04 - accuracy: 1.0000 - val_loss: 0.2027 - val_accuracy: 0.9209 - 11s/epoch - 606ms/step
# Epoch 39/50
# 18/18 - 9s - loss: 4.9704e-04 - accuracy: 1.0000 - val_loss: 0.2026 - val_accuracy: 0.9209 - 9s/epoch - 522ms/step
# Epoch 40/50
# 18/18 - 10s - loss: 4.6580e-04 - accuracy: 1.0000 - val_loss: 0.2040 - val_accuracy: 0.9209 - 10s/epoch - 570ms/step
# Epoch 41/50
# 18/18 - 10s - loss: 4.4361e-04 - accuracy: 1.0000 - val_loss: 0.2059 - val_accuracy: 0.9209 - 10s/epoch - 555ms/step
# Epoch 42/50
# 18/18 - 10s - loss: 4.1964e-04 - accuracy: 1.0000 - val_loss: 0.2045 - val_accuracy: 0.9209 - 10s/epoch - 534ms/step
# Epoch 43/50
# 18/18 - 10s - loss: 3.9831e-04 - accuracy: 1.0000 - val_loss: 0.2067 - val_accuracy: 0.9209 - 10s/epoch - 560ms/step
# Epoch 44/50
# 18/18 - 10s - loss: 3.7931e-04 - accuracy: 1.0000 - val_loss: 0.2075 - val_accuracy: 0.9209 - 10s/epoch - 567ms/step
# Epoch 45/50
# 18/18 - 10s - loss: 3.6189e-04 - accuracy: 1.0000 - val_loss: 0.2083 - val_accuracy: 0.9209 - 10s/epoch - 557ms/step
# Epoch 46/50
# 18/18 - 10s - loss: 3.4418e-04 - accuracy: 1.0000 - val_loss: 0.2089 - val_accuracy: 0.9209 - 10s/epoch - 556ms/step
# Epoch 47/50
# 18/18 - 9s - loss: 3.3111e-04 - accuracy: 1.0000 - val_loss: 0.2097 - val_accuracy: 0.9209 - 9s/epoch - 527ms/step
# Epoch 48/50
# 18/18 - 10s - loss: 3.1573e-04 - accuracy: 1.0000 - val_loss: 0.2104 - val_accuracy: 0.9209 - 10s/epoch - 553ms/step
# Epoch 49/50
# 18/18 - 10s - loss: 3.0204e-04 - accuracy: 1.0000 - val_loss: 0.2110 - val_accuracy: 0.9209 - 10s/epoch - 543ms/step
# Epoch 50/50
# 18/18 - 10s - loss: 2.8909e-04 - accuracy: 1.0000 - val_loss: 0.2118 - val_accuracy: 0.9209 - 10s/epoch - 581ms/step
# 5/5 [==============================] - 2s 380ms/step - loss: 0.2118 - accuracy: 0.9209
#
#  Fold 5 - DenseNet Validation Accuracy: 0.9208633303642273
#
# 10/10 [==============================] - 2s 172ms/step - loss: 0.3772 - acc: 0.8771
# 10/10 [==============================] - 7s 746ms/step - loss: 0.4610 - acc: 0.8970
# 10/10 [==============================] - 5s 502ms/step - loss: 0.5616 - accuracy: 0.7110
# 10/10 [==============================] - 4s 397ms/step - loss: 0.3764 - accuracy: 0.9269
# Average CNN Cross Validation Accuracy for first step: 0.6864285707473755
# CNN Test accuracy for first step: 0.7066666483879089
#
# Average VGG16 Cross Validation Accuracy for first step: 0.7628571391105652
# VGG16 Test accuracy for first step: 0.7616666555404663
#
# Average ResNet Cross Validation Accuracy for first step: 0.645714282989502
# ResNet Test accuracy for first step: 0.6016666889190674
#
# Average DenseNet Cross Validation Accuracy for first step: 0.8135714292526245
# DenseNet Test accuracy for first step: 0.8199999928474426
#
# Average CNN Cross Validation Accuracy for second step: 0.8441007256507873
# CNN Test accuracy for  second step: 0.8770763874053955
#
# Average VGG16 Cross Validation Accuracy for  second step: 0.9128160357475281
# VGG16 Test accuracy for  second  step: 0.8970099687576294
#
# Average ResNet Cross Validation Accuracy for  second step: 0.6810380339622497
# ResNet Test accuracy for  second step: 0.7109634280204773
#
# Average DenseNet Cross Validation Accuracy for  second step: 0.9127440929412842
# DenseNet Test accuracy for  second step: 0.9269102811813354

# %% [markdown]
# #### Cross validation and accuracy results of the first step

# %%
print(f"Average CNN Cross Validation Accuracy for first step: {np.mean(acc_scores_cnn)}")
print('CNN Test accuracy for first step:', score_cnn[1], '\n')

print(f"Average VGG16 Cross Validation Accuracy for first step: {np.mean(acc_scores_vgg16)}")
print('VGG16 Test accuracy for first step:', score_vgg16[1], '\n')

print(f"Average ResNet Cross Validation Accuracy for first step: {np.mean(acc_scores_resnet)}")
print('ResNet Test accuracy for first step:', score_resnet[1], '\n')

print(f"Average DenseNet Cross Validation Accuracy for first step: {np.mean(acc_scores_densenet)}")
print('DenseNet Test accuracy for first step:', score_densenet[1], '\n')
# Out:
# Average CNN Cross Validation Accuracy for first step: 0.6864285707473755
# CNN Test accuracy for first step: 0.7066666483879089
#
# Average VGG16 Cross Validation Accuracy for first step: 0.7628571391105652
# VGG16 Test accuracy for first step: 0.7616666555404663
#
# Average ResNet Cross Validation Accuracy for first step: 0.645714282989502
# ResNet Test accuracy for first step: 0.6016666889190674
#
# Average DenseNet Cross Validation Accuracy for first step: 0.8135714292526245
# DenseNet Test accuracy for first step: 0.8199999928474426

# %% [markdown]
# #### Cross validation, and accuracy results of the second step

# %%
print(f"Average CNN Cross Validation Accuracy for second step: {np.mean(acc_scores_cnn2)}")
print('CNN Test accuracy for  second step:', score_cnn2[1], '\n')

print(f"Average VGG16 Cross Validation Accuracy for  second step: {np.mean(acc_scores_vgg162)}")
print('VGG16 Test accuracy for  second  step:', score_vgg162[1], '\n')

print(f"Average ResNet Cross Validation Accuracy for  second step: {np.mean(acc_scores_resnet2)}")
print('ResNet Test accuracy for  second step:', score_resnet2[1], '\n')

print(f"Average DenseNet Cross Validation Accuracy for  second step: {np.mean(acc_scores_densenet2)}")
print('DenseNet Test accuracy for  second step:', score_densenet2[1], '\n')
# Out:
# Average CNN Cross Validation Accuracy for second step: 0.8441007256507873
# CNN Test accuracy for  second step: 0.8770763874053955
#
# Average VGG16 Cross Validation Accuracy for  second step: 0.9128160357475281
# VGG16 Test accuracy for  second  step: 0.8970099687576294
#
# Average ResNet Cross Validation Accuracy for  second step: 0.6810380339622497
# ResNet Test accuracy for  second step: 0.7109634280204773
#
# Average DenseNet Cross Validation Accuracy for  second step: 0.9127440929412842
# DenseNet Test accuracy for  second step: 0.9269102811813354

# %% [markdown]
# #### Other Performance metrics

# %% [markdown]
# ##### Results and plots for the first step hierarchical binary classification

# %%
# Define a function to calculate evaluation metrics
def calculate_metrics(y_true, y_pred):
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='binary')
    recall = recall_score(y_true, y_pred, average='binary')
    f1 = f1_score(y_true, y_pred, average='binary')
    auc = roc_auc_score(y_true, y_pred)
    bma = balanced_accuracy_score(y_true, y_pred)
    return accuracy, precision, recall, f1, auc, bma

# Get predictions for the test data
y_pred_cnn = model_cnn.predict(x_test)
y_pred_vgg16 = model_vgg16.predict(x_test)
y_pred_resnet = model_resnet.predict(x_test)
y_pred_densenet = model_densenet.predict(x_test)

# Convert predictions to binary values (0 or 1) using a threshold (e.g., 0.5)
threshold = 0.5
y_pred_cnn_bin = (y_pred_cnn > threshold).astype(int)
y_pred_vgg16_bin = (y_pred_vgg16 > threshold).astype(int)
y_pred_resnet_bin = (y_pred_resnet > threshold).astype(int)
y_pred_densenet_bin = (y_pred_densenet > threshold).astype(int)

# Calculate evaluation metrics for each model on the test data
acc_cnn, prec_cnn, rec_cnn, f1_cnn, auc_cnn, bma_cnn = calculate_metrics(y_test, y_pred_cnn_bin)
acc_vgg16, prec_vgg16, rec_vgg16, f1_vgg16, auc_vgg16, bma_vgg16 = calculate_metrics(y_test, y_pred_vgg16_bin)
acc_resnet, prec_resnet, rec_resnet, f1_resnet, auc_resnet, bma_resnet = calculate_metrics(y_test, y_pred_resnet_bin)
acc_densenet, prec_densenet, rec_densenet, f1_densenet, auc_densenet, bma_densenet = calculate_metrics(y_test, y_pred_densenet_bin)

# Print evaluation metrics for each model
print("CNN Model Metrics:")
print("Accuracy:", acc_cnn)
print("Precision:", prec_cnn)
print("Recall:", rec_cnn)
print("F1-score:", f1_cnn)
print("AUC:", auc_cnn)
print("Balanced Accuracy:", bma_cnn)

print("\nVGG16 Model Metrics:")
print("Accuracy:", acc_vgg16)
print("Precision:", prec_vgg16)
print("Recall:", rec_vgg16)
print("F1-score:", f1_vgg16)
print("AUC:", auc_vgg16)
print("Balanced Accuracy:", bma_vgg16)

print("\nResNet Model Metrics:")
print("Accuracy:", acc_resnet)
print("Precision:", prec_resnet)
print("Recall:", rec_resnet)
print("F1-score:", f1_resnet)
print("AUC:", auc_resnet)
print("Balanced Accuracy:", bma_resnet)

print("\nDenseNet Model Metrics:")
print("Accuracy:", acc_densenet)
print("Precision:", prec_densenet)
print("Recall:", rec_densenet)
print("F1-score:", f1_densenet)
print("AUC:", auc_densenet)
print("Balanced Accuracy:", bma_densenet)
# Out:
# 19/19 [==============================] - 4s 209ms/step
# 19/19 [==============================] - 15s 783ms/step
# 19/19 [==============================] - 11s 499ms/step
# 19/19 [==============================] - 10s 400ms/step
# CNN Model Metrics:
# Accuracy: 0.7066666666666667
# Precision: 0.6890243902439024
# Recall: 0.7533333333333333
# F1-score: 0.7197452229299363
# AUC: 0.7066666666666667
# Balanced Accuracy: 0.7066666666666667
#
# VGG16 Model Metrics:
# Accuracy: 0.7616666666666667
# Precision: 0.8152610441767069
# Recall: 0.6766666666666666
# F1-score: 0.7395264116575592
# AUC: 0.7616666666666667
# Balanced Accuracy: 0.7616666666666667
#
# ResNet Model Metrics:
# Accuracy: 0.6016666666666667
# Precision: 0.597444089456869
# Recall: 0.6233333333333333
# F1-score: 0.6101141924959216
# AUC: 0.6016666666666667
# Balanced Accuracy: 0.6016666666666666
#
# DenseNet Model Metrics:
# Accuracy: 0.82
# Precision: 0.8096774193548387
# Recall: 0.8366666666666667
# F1-score: 0.822950819672131
# AUC: 0.82
# Balanced Accuracy: 0.8200000000000001

# %%
# plot the training and validation accuracy and loss at each epoch for the first step classification

#CNN
loss = history_cnn.history['loss']
val_loss = history_cnn.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss (CNN)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()


acc = history_cnn.history['acc']
val_acc = history_cnn.history['val_acc']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

#VGG16
loss = history_vgg16.history['loss']
val_loss = history_vgg16.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss (VGG16)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()


acc = history_vgg16.history['acc']
val_acc = history_vgg16.history['val_acc']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy (VGG16)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()


#RESNET
loss = history_resnet.history['loss']
val_loss = history_resnet.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss (RESNET)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()


acc = history_resnet.history['accuracy']
val_acc = history_resnet.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy (RESNET)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()


#DENSENET
loss = history_densenet.history['loss']
val_loss = history_densenet.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss (DENSENET)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()


acc = history_densenet.history['accuracy']
val_acc = history_densenet.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy (RESNET)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# AUC Curve for the models
from sklearn.metrics import roc_curve
plt.figure(figsize=(16, 8))

# First row - CNN and VGG16
plt.subplot(2, 2, 1)
fpr_cnn, tpr_cnn, thresholds_cnn = roc_curve(y_test, y_pred_cnn_bin)
plt.plot(fpr_cnn, tpr_cnn, label="ROC Curve (AUC = {:.2f})".format(auc_cnn))
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("First Receiver Operating Characteristic (CNN)")
plt.legend()

plt.subplot(2, 2, 2)
fpr_vgg16, tpr_vgg16, thresholds_vgg16 = roc_curve(y_test, y_pred_vgg16_bin)
plt.plot(fpr_vgg16, tpr_vgg16, label="ROC Curve (AUC = {:.2f})".format(auc_vgg16))
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("First Receiver Operating Characteristic (VGG16)")
plt.legend()

# Second row - ResNet and DenseNet
plt.subplot(2, 2, 3)
fpr_resnet, tpr_resnet, thresholds_resnet = roc_curve(y_test, y_pred_resnet_bin)
plt.plot(fpr_resnet, tpr_resnet, label="ROC Curve (AUC = {:.2f})".format(auc_resnet))
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("First Receiver Operating Characteristic (ResNet)")
plt.legend()

plt.subplot(2, 2, 4)
fpr_densenet, tpr_densenet, thresholds_densenet = roc_curve(y_test, y_pred_densenet_bin)
plt.plot(fpr_densenet, tpr_densenet, label="ROC Curve (AUC = {:.2f})".format(auc_densenet))
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("First Receiver Operating Characteristic (DenseNet)")
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Plot fractional incorrect misclassifications for all the models
plt.figure(figsize=(14, 10))

# CNN
plt.subplot(2, 2, 1)
cm = confusion_matrix(y_test, y_pred_cnn_bin)
incorr_fraction = 1 - np.diag(cm) / np.sum(cm, axis=1)
plt.bar(np.arange(2), incorr_fraction)
plt.xlabel('True Label')
plt.ylabel('Fraction of incorrect predictions')
plt.title('First step: CNN')

# VGG16
plt.subplot(2, 2, 2)
cm = confusion_matrix(y_test, y_pred_vgg16_bin)
incorr_fraction = 1 - np.diag(cm) / np.sum(cm, axis=1)
plt.bar(np.arange(2), incorr_fraction)
plt.xlabel('True Label')
plt.ylabel('Fraction of incorrect predictions')
plt.title('First step: VGG16')

# ResNet
plt.subplot(2, 2, 3)
cm = confusion_matrix(y_test, y_pred_resnet_bin)
incorr_fraction = 1 - np.diag(cm) / np.sum(cm, axis=1)
plt.bar(np.arange(2), incorr_fraction)
plt.xlabel('True Label')
plt.ylabel('First step Fraction of incorrect predictions')
plt.title('First step: ResNet')

# DenseNet
plt.subplot(2, 2, 4)
cm = confusion_matrix(y_test, y_pred_densenet_bin)
incorr_fraction = 1 - np.diag(cm) / np.sum(cm, axis=1)
plt.bar(np.arange(2), incorr_fraction)
plt.xlabel('True Label')
plt.ylabel('Fraction of incorrect predictions')
plt.title('First step: DenseNet')

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Results and plots for the second step hierarchical binary classification

# %%
# Get predictions for the test data for the second step
y_pred_cnn_step2 = model_cnn2.predict(x_test_step2)
y_pred_vgg16_step2 = model_vgg162.predict(x_test_step2)
y_pred_resnet_step2 = model_resnet2.predict(x_test_step2)
y_pred_densenet_step2 = model_densenet2.predict(x_test_step2)

# Convert predictions to binary values (0 or 1) using a threshold (e.g., 0.5)
y_pred_cnn_step2_bin = (y_pred_cnn_step2 > threshold).astype(int)
y_pred_vgg16_step2_bin = (y_pred_vgg16_step2 > threshold).astype(int)
y_pred_resnet_step2_bin = (y_pred_resnet_step2 > threshold).astype(int)
y_pred_densenet_step2_bin = (y_pred_densenet_step2 > threshold).astype(int)

# Calculate evaluation metrics for each model on the test data for the second step
acc_cnn_step2, prec_cnn_step2, rec_cnn_step2, f1_cnn_step2, auc_cnn_step2, bma_cnn_step2 = calculate_metrics(y_test_step2, y_pred_cnn_step2_bin)
acc_vgg16_step2, prec_vgg16_step2, rec_vgg16_step2, f1_vgg16_step2, auc_vgg16_step2, bma_vgg16_step2 = calculate_metrics(y_test_step2, y_pred_vgg16_step2_bin)
acc_resnet_step2, prec_resnet_step2, rec_resnet_step2, f1_resnet_step2, auc_resnet_step2, bma_resnet_step2 = calculate_metrics(y_test_step2, y_pred_resnet_step2_bin)
acc_densenet_step2, prec_densenet_step2, rec_densenet_step2, f1_densenet_step2, auc_densenet_step2, bma_densenet_step2 = calculate_metrics(y_test_step2, y_pred_densenet_step2_bin)

# Print evaluation metrics for each model for the second step
print("CNN Model Metrics for the Second Step:")
print("Accuracy:", acc_cnn_step2)
print("Precision:", prec_cnn_step2)
print("Recall:", rec_cnn_step2)
print("F1-score:", f1_cnn_step2)
print("AUC:", auc_cnn_step2)
print("Balanced Accuracy:", bma_cnn_step2)

print("\nVGG16 Model Metrics for the Second Step:")
print("Accuracy:", acc_vgg16_step2)
print("Precision:", prec_vgg16_step2)
print("Recall:", rec_vgg16_step2)
print("F1-score:", f1_vgg16_step2)
print("AUC:", auc_vgg16_step2)
print("Balanced Accuracy:", bma_vgg16_step2)

print("\nResNet Model Metrics for the Second Step:")
print("Accuracy:", acc_resnet_step2)
print("Precision:", prec_resnet_step2)
print("Recall:", rec_resnet_step2)
print("F1-score:", f1_resnet_step2)
print("AUC:", auc_resnet_step2)
print("Balanced Accuracy:", bma_resnet_step2)

print("\nDenseNet Model Metrics for the Second Step:")
print("Accuracy:", acc_densenet_step2)
print("Precision:", prec_densenet_step2)
print("Recall:", rec_densenet_step2)
print("F1-score:", f1_densenet_step2)
print("AUC:", auc_densenet_step2)
print("Balanced Accuracy:", bma_densenet_step2)
# Out:
# 10/10 [==============================] - 2s 163ms/step
# 10/10 [==============================] - 6s 527ms/step
# 10/10 [==============================] - 6s 425ms/step
# 10/10 [==============================] - 8s 376ms/step
# CNN Model Metrics for the Second Step:
# Accuracy: 0.8770764119601329
# Precision: 0.8125
# Recall: 0.8888888888888888
# F1-score: 0.8489795918367347
# AUC: 0.8792270531400966
# Balanced Accuracy: 0.8792270531400965
#
# VGG16 Model Metrics for the Second Step:
# Accuracy: 0.8970099667774086
# Precision: 0.8467741935483871
# Recall: 0.8974358974358975
# F1-score: 0.8713692946058093
# AUC: 0.89708751393534
# Balanced Accuracy: 0.89708751393534
#
# ResNet Model Metrics for the Second Step:
# Accuracy: 0.7109634551495017
# Precision: 0.6363636363636364
# Recall: 0.5982905982905983
# F1-score: 0.6167400881057269
# AUC: 0.6904496469713861
# Balanced Accuracy: 0.6904496469713861
#
# DenseNet Model Metrics for the Second Step:
# Accuracy: 0.9269102990033222
# Precision: 0.8991596638655462
# Recall: 0.9145299145299145
# F1-score: 0.9067796610169491
# AUC: 0.9246562616127832
# Balanced Accuracy: 0.9246562616127834

# %%
# plot the training and validation accuracy and loss at each epoch for the second step classification

#CNN
loss2 = history_cnn2.history['loss']
val_loss2 = history_cnn2.history['val_loss']
epochs2 = range(1, len(loss2) + 1)
plt.plot(epochs2, loss2, 'y', label='Training loss')
plt.plot(epochs2, val_loss2, 'r', label='Validation loss')
plt.title('Second Training and validation loss (CNN)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()


acc2 = history_cnn2.history['acc']
val_acc2 = history_cnn2.history['val_acc']
plt.plot(epochs2, acc2, 'y', label='Training acc')
plt.plot(epochs2, val_acc2, 'r', label='Validation acc')
plt.title('Second step Training and validation accuracy (CNN)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

#VGG16
loss2 = history_vgg162.history['loss']
val_loss2 = history_vgg162.history['val_loss']
epochs2 = range(1, len(loss2) + 1)
plt.plot(epochs2, loss2, 'y', label='Training loss')
plt.plot(epochs2, val_loss2, 'r', label='Validation loss')
plt.title('Second Training and validation loss (VGG16)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()


acc2 = history_vgg162.history['acc']
val_acc2 = history_vgg162.history['val_acc']
plt.plot(epochs2, acc2, 'y', label='Training acc')
plt.plot(epochs2, val_acc2, 'r', label='Validation acc')
plt.title('Second Training and validation accuracy (VGG16)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()


#RESNET
loss2 = history_resnet2.history['loss']
val_loss2 = history_resnet2.history['val_loss']
epochs2 = range(1, len(loss2) + 1)
plt.plot(epochs2, loss2, 'y', label='Training loss')
plt.plot(epochs2, val_loss2, 'r', label='Validation loss')
plt.title('Second Training and validation loss (RESNET)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()


acc2 = history_resnet2.history['accuracy']
val_acc2 = history_resnet2.history['val_accuracy']
plt.plot(epochs2, acc2, 'y', label='Training acc')
plt.plot(epochs2, val_acc2, 'r', label='Validation acc')
plt.title('Second Training and validation accuracy (RESNET)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()


#DENSENET
loss2 = history_densenet2.history['loss']
val_loss2 = history_densenet2.history['val_loss']
epochs2 = range(1, len(loss2) + 1)
plt.plot(epochs2, loss2, 'y', label='Training loss')
plt.plot(epochs2, val_loss2, 'r', label='Validation loss')
plt.title('Second Training and validation loss (DENSENET)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()


acc2 = history_densenet2.history['accuracy']
val_acc2 = history_densenet2.history['val_accuracy']
plt.plot(epochs2, acc2, 'y', label='Training acc')
plt.plot(epochs2, val_acc2, 'r', label='Validation acc')
plt.title('Second Training and validation accuracy (RESNET)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(16, 8))

# First row - CNN and VGG16
plt.subplot(2, 2, 1)
fpr_cnn, tpr_cnn, thresholds_cnn = roc_curve(y_test_step2, y_pred_cnn_step2_bin)
plt.plot(fpr_cnn, tpr_cnn, label="ROC Curve (AUC = {:.2f})".format(auc_cnn_step2))
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Second Receiver Operating Characteristic (CNN)")
plt.legend()

plt.subplot(2, 2, 2)
fpr_vgg16, tpr_vgg16, thresholds_vgg16 = roc_curve(y_test_step2, y_pred_vgg16_step2_bin)
plt.plot(fpr_vgg16, tpr_vgg16, label="ROC Curve (AUC = {:.2f})".format(auc_vgg16_step2))
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Second Receiver Operating Characteristic (VGG16)")
plt.legend()

# Second row - ResNet and DenseNet
plt.subplot(2, 2, 3)
fpr_resnet, tpr_resnet, thresholds_resnet = roc_curve(y_test_step2, y_pred_resnet_step2_bin)
plt.plot(fpr_resnet, tpr_resnet, label="ROC Curve (AUC = {:.2f})".format(auc_resnet_step2))
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Second Receiver Operating Characteristic (ResNet)")
plt.legend()

plt.subplot(2, 2, 4)
fpr_densenet, tpr_densenet, thresholds_densenet = roc_curve(y_test_step2, y_pred_densenet_step2_bin)
plt.plot(fpr_densenet, tpr_densenet, label="ROC Curve (AUC = {:.2f})".format(auc_densenet_step2))
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Second Receiver Operating Characteristic (DenseNet)")
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Plot fractional incorrect misclassifications for all the models
plt.figure(figsize=(14, 10))

# CNN
plt.subplot(2, 2, 1)
cm2 = confusion_matrix(y_test_step2, y_pred_cnn_step2_bin)
incorr_fraction = 1 - np.diag(cm2) / np.sum(cm2, axis=1)
plt.bar(np.arange(2), incorr_fraction)
plt.xlabel('True Label')
plt.ylabel('Fraction of incorrect predictions')
plt.title('Second step: CNN')

# VGG16
plt.subplot(2, 2, 2)
cm = confusion_matrix(y_test_step2, y_pred_vgg16_step2_bin)
incorr_fraction = 1 - np.diag(cm) / np.sum(cm, axis=1)
plt.bar(np.arange(2), incorr_fraction)
plt.xlabel('True Label')
plt.ylabel('Fraction of incorrect predictions')
plt.title('Second step: VGG16')

# ResNet
plt.subplot(2, 2, 3)
cm = confusion_matrix(y_test_step2, y_pred_resnet_step2_bin)
incorr_fraction = 1 - np.diag(cm) / np.sum(cm, axis=1)
plt.bar(np.arange(2), incorr_fraction)
plt.xlabel('True Label')
plt.ylabel('Fraction of incorrect predictions')
plt.title('Second step: ResNet')

# DenseNet
plt.subplot(2, 2, 4)
cm = confusion_matrix(y_test_step2, y_pred_densenet_step2_bin)
incorr_fraction = 1 - np.diag(cm) / np.sum(cm, axis=1)
plt.bar(np.arange(2), incorr_fraction)
plt.xlabel('True Label')
plt.ylabel('Second Step Fraction of incorrect predictions')
plt.title('Second step: DenseNet')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### OVERALL BALANCED MULTICLASS ACCURACY

# %%
# Calculate the accuracy for each class (Benign, Melanoma, Seborrheic) and BMA for each model
models = ['CNN', 'VGG16', 'ResNet', 'DenseNet']

for model_name in models:
    print(f"\nMetrics for {model_name} Model:")
    
    # First Step (Benign vs Others)
    y_pred_bin = globals()[f"y_pred_{model_name.lower()}_bin"]
    cm_first = confusion_matrix(y_test, y_pred_bin)
    TN = cm_first[0, 0]
    FP = cm_first[0, 1]
    FN = cm_first[1, 0]
    TP = cm_first[1, 1]
    
    benign_accuracy = TN / (TN + FP)
    print('The accuracy of the benign class in the first step is:', benign_accuracy)
    
    # Second Step (Melanoma vs Seborrheic)
    y_pred_step2_bin = globals()[f"y_pred_{model_name.lower()}_step2_bin"]
    cm_second = confusion_matrix(y_test_step2, y_pred_step2_bin)
    TN_2 = cm_second[0, 0]
    FP_2 = cm_second[0, 1]
    FN_2 = cm_second[1, 0]
    TP_2 = cm_second[1, 1]

    melanoma_accuracy = TN_2 / (TN_2 + FP_2)
    print('The accuracy of the melanoma class in the second step is:', melanoma_accuracy)

    seborrheic_accuracy = TP_2 / (TP_2 + FN_2)
    print('The accuracy of the seborrheic class in the second step is:', seborrheic_accuracy)
    # Calculate BMA
    bma = 1/3 * (benign_accuracy + melanoma_accuracy + seborrheic_accuracy)
    print('Balanced Model Accuracy (BMA):', bma)
# Out:
# Metrics for CNN Model:
# The accuracy of the benign class in the first step is: 0.66
# The accuracy of the melanoma class in the second step is: 0.8695652173913043
# The accuracy of the seborrheic class in the second step is: 0.8888888888888888
# Balanced Model Accuracy (BMA): 0.8061513687600643
#
# Metrics for VGG16 Model:
# The accuracy of the benign class in the first step is: 0.8466666666666667
# The accuracy of the melanoma class in the second step is: 0.8967391304347826
# The accuracy of the seborrheic class in the second step is: 0.8974358974358975
# Balanced Model Accuracy (BMA): 0.8802805648457822
#
# Metrics for ResNet Model:
# The accuracy of the benign class in the first step is: 0.58
# The accuracy of the melanoma class in the second step is: 0.782608695652174
# The accuracy of the seborrheic class in the second step is: 0.5982905982905983
# Balanced Model Accuracy (BMA): 0.6536330979809241
#
# Metrics for DenseNet Model:
# The accuracy of the benign class in the first step is: 0.8033333333333333
# The accuracy of the melanoma class in the second step is: 0.9347826086956522
# The accuracy of the seborrheic class in the second step is: 0.9145299145299145
# Balanced Model Accuracy (BMA): 0.8842152855196332

# %% [markdown]
# ### OVERALL PIPELINE - THE PREDICTIVE MODEL FOR DENSENET

# %%
n = 12
img = x_test[n]
plt.imshow(img)
input_img = np.expand_dims(img, axis=0)  # Expand dims so the input is (num images, x, y, c)

# Define the list of models for each step
step1_models = ['CNN', 'VGG16', 'ResNet', 'DenseNet']
step2_models = ['model_cnn2', 'model_vgg162', 'model_resnet2', 'model_densenet2']

for model_name, step2_model_name in zip(step1_models, step2_models):
    prediction_first = globals()[f"model_{model_name.lower()}"].predict(input_img)[0]
    if prediction_first < 0.5:
        prediction_label = "benign"
    else:
        prediction_second = globals()[step2_model_name].predict(input_img)[0]
        prediction_label = "melanoma" if prediction_second < 0.5 else "seborrheic_keratosis"

    print(f"\nThe {model_name} prediction for this image is:", prediction_label, '\n')

# Mapping the actual label to a label name
if y_test[n] == 0:
    actual_label = "benign"
else:
    actual_label = "melanoma" if y_test_step2[n] == 0 else "seborrheic_keratosis"

print("\nThe actual label for this image is:", actual_label)
# Out:
# 1/1 [==============================] - 0s 32ms/step
#
# The CNN prediction for this image is: benign
#
# 1/1 [==============================] - 0s 128ms/step
#
# The VGG16 prediction for this image is: benign
#
# 1/1 [==============================] - 0s 142ms/step
#
# The ResNet prediction for this image is: benign
#
# 1/1 [==============================] - 0s 112ms/step
#
# The DenseNet prediction for this image is: benign
#
#
# The actual label for this image is: benign

# %% [markdown]
# ### Work Done
